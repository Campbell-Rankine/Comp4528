# %%
### - CLAB 1 - ###

##- standard imports -##
import math
import numpy as np
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv
import os
# %matplotlib inline

# %%
### - Python warmup - ###

def Task1():
    a = np.array([[1,2,3],[5, 2, 20]])
    #b = a[2,:]
    f = np.random.randn(200,1)
    g = f[f>0]
    x = np.zeros(50) + 0.5
    y = 0.5*(np.ones(50))
    z = x + y
    a1 = np.linspace(1,200)
    b1 = a1[::1]
    b1[b1<35] = 0
    return[a, f, g, x, y, z, a1, b1]

# %%
### - Task 2 - ###
img1 = cv.imread('/Users/bigc/Documents/Comp/4528/CLab-1/image1.jpg')
print(os.path.exists('/Users/bigc/Documents/Comp/4528/CLab-1'))
img1 = cv.resize(img1, (384,256))

fig, ax = plt.subplots(2)

ax[0].imshow(img1)
    
gImg1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
img2 = np.zeros_like(img1)
img2[:,:,0] = gImg1
img2[:,:,1] = gImg1
img2[:,:,2] = gImg1

print(img2.shape)

ax[1].imshow(gImg1, cmap="gray")

#cv.imshow('gray', gImg1)
# Out:
# True
# (256, 384, 3)
